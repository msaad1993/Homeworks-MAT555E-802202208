# %% [markdown]
# # Question 1
#
# Write a python function that returns $2\sin(x^2) + \ln(|x|) + 1$ for a given real number $x$.

# %%
from math import sin, log

def Eq(x):
    output = 2*sin(x**2) + log(abs(x)) + 1
    return output

Eq(2)
# Out:
# 0.17954218994408888

# %% [markdown]
# # Question 2
#
# Write a python function that takes
#
# * A function `f(x)`
# * A pair of real numbers `(a,b)`
# * An integer `N`
#
# as input and returns the Riemann sum of `f(x)` on the interval `[a,b]` with `N` equal subdivisions.

# %%
def fx(x):
  return x**(1/2)

def Reimann(fx, N, rng):
  a,b = rng
  t_w = b - a
  p_w = t_w/N
  Area = 0

  for i in range(1,N+1):
    Area += p_w * fx(a + p_w*i)
  
  return Area

Reimann(fx, 4, (0.5,3.5))
# Out:
# 4.546041479765746

# %% [markdown]
# # Question 3
#
# * Pull 100 uniformly random numbers from the interval $[0,1]$ as an array `xs`.
# * Add 0 at the beginning of the array, and 1.0 at the end.
# * Sort the array `xs` from smallest to the largest.
# * Calculate its discrete derivative `ys`, i.e. let $y_i = x_{i+1} - x_i$

# %%
import numpy as np

xs = np.random.uniform(0,1,100)
xs = np.concatenate(([0],xs,[1]))
xs_sorted = np.sort(xs)
ys = np.diff(xs_sorted)

# %% [markdown]
# # Question 4
#
# * Pull 100 uniformly random numbers from the interval $[0,1]$ into an array `xs`.
# * Pull 100 random numbers from the Gaussion distribution with $\mu=0$ and $\sigma=1.0$ into an array `ys`.
# * Scatter plot `xs` against `ys` using `matplotlib`

# %%
import numpy as np
import matplotlib.pyplot as plt

xs = np.random.uniform(0,1,100)
ys = np.random.normal(0,1,100)

plt.scatter(xs,ys)
plt.xlabel("Uniform random distribution")
plt.ylabel("Gaussian Normal distribution")
plt.title("xs vs ys")
# Out:
# Text(0.5, 1.0, 'xs vs ys')

# %% [markdown]
# # Question 5
#
# Using the `numpy` library
#
# * Pull a random $100\times 100$ matrix
# * Calculate its 100-th power
# * Calculate its eigen-values
# * Calculate is [Singular Value Decomposition](https://numpy.org/doc/stable/reference/generated/numpy.linalg.svd.html)

# %%
arr = np.random.rand(100,100)
arr_pow = np.linalg.matrix_power(arr,100)
eig_val, eig_vec = np.linalg.eig(arr_pow)
u, s, vh = np.linalg.svd(arr_pow)
print (u, s, vh)
# Out:
# [[-0.09598589  0.92830098  0.24943695 ...  0.03723323  0.01617559
#   -0.17543612]
#  [-0.10829432  0.01932275 -0.07581673 ... -0.07586969  0.00386685
#   -0.05120863]
#  [-0.10028929 -0.00841073 -0.1740579  ... -0.08014413  0.07943254
#   -0.1781203 ]
#  ...
#  [-0.0998723  -0.04089794 -0.02786403 ...  0.1075248   0.0462833
#   -0.11523805]
#  [-0.09733248  0.02527988  0.07604899 ... -0.00910152 -0.08888563
#    0.24271717]
#  [-0.10670505 -0.01312748  0.00145928 ... -0.02865686 -0.36395489
#   -0.01708701]] [7.68918384e+169 7.64726022e+153 7.64726022e+153 7.64726022e+153
#  7.64726022e+153 7.64726022e+153 7.64726022e+153 7.64726022e+153
#  7.64726022e+153 7.64726022e+153 7.64726022e+153 7.64726022e+153
#  7.64726022e+153 7.64726022e+153 7.64726022e+153 7.64726022e+153
#  7.64726022e+153 7.64726022e+153 7.64726022e+153 7.64726022e+153
#  7.64726022e+153 7.64726022e+153 7.64726022e+153 7.64726022e+153
#  7.64726022e+153 7.64726022e+153 7.64726022e+153 7.64726022e+153
#  7.64726022e+153 7.64726022e+153 7.64726022e+153 7.64726022e+153
#  7.64726022e+153 7.64726022e+153 7.64726022e+153 7.64726022e+153
#  7.64726022e+153 7.64726022e+153 7.64726022e+153 7.64726022e+153
#  7.64726022e+153 7.64726022e+153 7.64726022e+153 7.64726022e+153
#  7.64726022e+153 7.64726022e+153 7.64726022e+153 7.64726022e+153
#  7.64726022e+153 7.64726022e+153 7.64726022e+153 7.64726022e+153
#  7.64726022e+153 7.64726022e+153 7.64726022e+153 7.64726022e+153
#  7.64726022e+153 7.64726022e+153 7.64726022e+153 7.64726022e+153
#  7.64726022e+153 7.64726022e+153 7.64726022e+153 7.64726022e+153
#  7.64726022e+153 7.64726022e+153 7.64726022e+153 7.64726022e+153
#  7.64726022e+153 7.64726022e+153 7.64726022e+153 7.64726022e+153
#  7.64726022e+153 7.64726022e+153 7.64726022e+153 7.64726022e+153
#  7.64726022e+153 7.64726022e+153 7.64726022e+153 7.64726022e+153
#  7.64726022e+153 7.64726022e+153 7.64726022e+153 7.64726022e+153
#  7.64726022e+153 7.64726022e+153 7.64726022e+153 7.64726022e+153
#  7.64726022e+153 7.64726022e+153 7.64726022e+153 7.64726022e+153
#  7.64726022e+153 7.64726022e+153 7.64726022e+153 7.64726022e+153
#  7.64726022e+153 7.64726022e+153 7.64726022e+153 1.72696935e+153] [[-0.09639384 -0.09342418 -0.10868178 ... -0.10524844 -0.09968114
#   -0.10787359]
#  [ 0.         -0.03657036  0.06836965 ...  0.02443135  0.03751001
#    0.15401334]
#  [ 0.          0.10029318 -0.1151506  ...  0.12731519  0.13307403
#    0.00131172]
#  ...
#  [ 0.          0.17640732  0.00232654 ... -0.02419141 -0.03815466
#    0.07323524]
#  [ 0.         -0.04601502 -0.01422412 ... -0.08267688  0.00473588
#   -0.0677263 ]
#  [-0.99534327  0.00904765  0.01052527 ...  0.01019277  0.0096536
#    0.010447  ]]

# %% [markdown]
# # Question 6
#
# * Pull the text of a novel by Dickens from the website of [Gutenberg Project](https://www.gutenberg.org/)
# * Remove all non-alphanumeric characters
# * Split the text into words and convert them into lower case
# * Count the number of distinct words in the  text
# * Count how many times each word occurs within the text

# %%
from urllib import request
import re
import nltk
nltk.download("punkt")

url = "http://www.gutenberg.org/files/766/766-0.txt"
response = request.urlopen(url)
raw = response.read()
text = raw.decode("utf-8")
text_clean = re.sub("[^A-Za-z0-9 ]", '', text)
word = nltk.word_tokenize(text_clean)
word_lower = [i.lower() for i in word]
ds_word = len(set(word_lower))
freq = nltk.FreqDist(word_lower)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %% [markdown]
# # Question 7
#
# * Write a python function `CountWords` that takes the URL for a text and returns the number of unique words within the text.
# * Write a python function `Top20Words` that takes the URL for a text and returns the most frequently appearing top 20 words within the text.

# %%
from urllib.request import urlopen
import nltk

def CountWords(url):
  data = urlopen(url)
  response = request.urlopen(url)
  raw = response.read()
  text = raw.decode("utf-8")
  text = re.sub("[^A-Za-z0-9 ]", '', text)
  tokens = nltk.word_tokenize(text)
  nunique = len(set(tokens))
  return nunique

def Top20Words(url):
  data = urlopen(url)
  response = request.urlopen(url)
  raw = response.read()
  text = raw.decode("utf-8")
  text = re.sub("[^A-Za-z0-9 ]", '', text)
  tokens = nltk.word_tokenize(text)
  tokens = [i.lower() for i in tokens]
  freq = nltk.FreqDist(word_lower)
  return freq.most_common(20)

url = "http://www.gutenberg.org/files/766/766-0.txt"
print(Top20Words(url))
print(CountWords(url))
# Out:
# [('the', 11583), ('i', 10515), ('and', 10320), ('to', 9315), ('of', 7703), ('a', 6899), ('in', 5470), ('was', 4576), ('my', 4401), ('that', 4392), ('it', 3858), ('her', 3208), ('me', 3046), ('you', 2942), ('he', 2940), ('with', 2910), ('as', 2785), ('said', 2687), ('had', 2665), ('his', 2508)]
# 39422

# %% [markdown]
# # Question 8
#
# * Pull the [IMKB](https://archive.ics.uci.edu/ml/machine-learning-databases/00247/data_akbilgic.xlsx) data from UCI using pandas.
# * Plot the TL based ISE and USD based ISE columns together in the same graph.
# * Calculate how many times `NIKKEI` was higher than `FTSE`.

# %%
import pandas as pd
import matplotlib.pyplot as plt


data = pd.read_excel("https://archive.ics.uci.edu/ml/machine-learning-databases/00247/data_akbilgic.xlsx", header=[0,1])
tl = data["TL BASED"]
usd = data["USD BASED"]

plt.figure()
plt.plot(tl, usd, "r.")
plt.xlabel("TL Based ISE")
plt.ylabel("USD Based ISE")
plt.title("USD vs TL BASED ISE")

data.head()
high_check = (data["imkb_x","NIKKEI"] > data["imkb_x","FTSE"]).sum()
print("NIKKEI was ",high_check," times higher than FTSE")
# Out:
# NIKKEI was  261  times higher than FTSE

# %% [markdown]
# # Question 9
#
# Using the [networkx](https://networkx.org/) library
#
# * Get the [adjacency matrix](https://en.wikipedia.org/wiki/Adjacency_matrix) of the [Peterson graph](https://en.wikipedia.org/wiki/Petersen_graph).
# * Calculate its eigen-values and eigen-vectors using the [numpy](https://numpy.org/) library.
# * Repeat the same for a [random 3-regular graph on 10 vertices](https://networkx.org/documentation/networkx-1.10/reference/generated/networkx.generators.random_graphs.random_regular_graph.html).

# %%
import networkx as nx
import numpy as np

#Peterson graph
graph = nx.petersen_graph()
nx.draw_shell(graph, nlist=[range(5, 10), range(5)],  font_weight='bold',node_color=range(10),cmap=plt.cm.Reds,font_color='r',style='dotted')
plt.show()

adj = nx.adjacency_matrix(graph)
eig_val, eig_vec = np.linalg.eig(adj.A)

# %%
import networkx as nx
import numpy as np
#Repeat for random 3-regular graph on 10 vectices
#Graph with 3 nodes and 10 edges
graph_2 = nx.generators.random_graphs.random_regular_graph(3, 10)
adj_2 = nx.adjacency_matrix(graph_2)
nx.draw_shell(graph_2, nlist=[range(3, 10), range(7)],  font_weight='bold',node_color=range(10),cmap=plt.cm.Reds,font_color='r',style='dotted')
plt.show()
#Eigenvalues and Eigenvectors
eig_val, eig_vec = np.linalg.eig(adj_2.A)
